# %%
import numpy as np
from scipy.stats import norm
S=25492
k=25550
T=4/365
R=0.07
sigma=0.0816
d1=(np.log(S/k)+(R+0.5*sigma**2)*T)/(sigma*np.sqrt(T))
d2=d1-sigma*np.sqrt(T)
put_price=k*np.exp(-R*T)*norm.cdf(-d2)-S*norm.cdf(-d1)
print("Fair Value of put price is",put_price)
# Out:
# Fair Value of put price is 107.48924739283757
